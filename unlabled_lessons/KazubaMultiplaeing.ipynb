# %%
isSimple = lambda x1,x2: (len(str(x1))==1 and len(str(x2))==1)
      
def multiKaz(x1,x2):
    x1=str(x1)
    x2=str(x2)
    
    print("-------NEW INTERATION---------")
    print(x1);
    print(x2);
    print("----------------")
    
    
    l1=len(x1);
    l2=len(x2);
    
    if(l1!=l2):
        if(l2>l1):
            x1 = "0"+x1;
        else:
            x2=x2+x1[l1-1:]
            x1="0"+x1[:l1-1]
            
    l= l1 if(l1>l2) else l2;
    
    a=int(x1[:(l/2)]);
    c=int(x2[:(l/2)]);
    b=int(x1[(l/2):]);
    d=int(x2[(l/2):]);
    
    print("---x,y---")
    print("---",x1,x2,"---")
    print("--a--b--c--d")
    print(a)
    print(b)
    print(c)
    print(d)
    
    ac=0;
    bd=0;
    adMcd=0;
    
    if not isSimple(a,c):
        ac=multiKaz(a,c);
    if isSimple(a,c):
        ac=a*c
        print("ac",ac)
          
    if not isSimple(b,d):
        bd=multiKaz(b,d);
    if isSimple(b,d):
        bd=b*d;
        print("bd",bd)
        
    apb=a+b;
    cpd=c+d;
    if not isSimple(apb,cpd):
        adMcb=multiKaz(apb,cpd);
    if isSimple(apb,cpd):
        adMcb=apb*cpd;
        print("(a+b)(c+d)")
        
    abPcb=adMcb-ac-bd
    print("---x,y---")
    print("!!!",x1,x2,"!!!")
    sum=(10 ** l)*ac+(10 ** (l/2))*abPcb+bd;
    
    print("--ac--")
    print(ac)
    print("--bd--")
    print(bd)
    print("--adMcb--")
    print(adMcb)
    print("---n---")
    print(l) 
    print("---ab+cb---")
    print(abPcb)
    print("----sum----")
    print(sum)
    return sum;

print("------BEGIN---------")
result = multiKaz(1234,5678);

print(result);
# Out:
# ------BEGIN---------
# -------NEW INTERATION---------
# 1234
# 5678
# ----------------
# -------NEW INTERATION---------
# 12
# 56
# ----------------
# ('ac', 5)
# ('bd', 12)
# -------NEW INTERATION---------
# 3
# 11
# ----------------
# ('ac', 0)
# ('bd', 3)
# (a+b)(c+d)
# ---x,y---
# ('---', '03', '11', '---')
# --a--b--c--d
# 0
# 3
# 1
# 1
# --ac--
# 0
# --bd--
# 3
# --adMcb--
# 6
# ---n---
# 2
# ---ab+cb---
# 3
# ----sum----
# 33
# ---x,y---
# ('---', '12', '56', '---')
# --a--b--c--d
# 1
# 2
# 5
# 6
# --ac--
# 5
# --bd--
# 12
# --adMcb--
# 33
# ---n---
# 2
# ---ab+cb---
# 16
# ----sum----
# 672
# -------NEW INTERATION---------
# 34
# 78
# ----------------
# ('ac', 21)
# ('bd', 32)
# -------NEW INTERATION---------
# 7
# 15
# ----------------
# ('ac', 0)
# ('bd', 35)
# (a+b)(c+d)
# ---x,y---
# ('---', '07', '15', '---')
# --a--b--c--d
# 0
# 7
# 1
# 5
# --ac--
# 0
# --bd--
# 35
# --adMcb--
# 42
# ---n---
# 2
# ---ab+cb---
# 7
# ----sum----
# 105
# ---x,y---
# ...
